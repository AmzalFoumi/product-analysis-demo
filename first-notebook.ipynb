# %% [markdown]
# # My First Jupyter Notebook

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# # Product Analysis

# %%
# Expanded product analysis dataset
import pandas as pd

data = {
    'ProductID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'ProductName': ['Laptop', 'Smartphone', 'Headphones', 'Monitor', 'Keyboard', 'Desk Chair', 'Webcam', 'Mouse', 'Tablet', 'Printer'],
    'Category': ['Electronics', 'Electronics', 'Accessories', 'Electronics', 'Accessories', 'Furniture', 'Accessories', 'Accessories', 'Electronics', 'Electronics'],
    'Brand': ['BrandA', 'BrandB', 'BrandC', 'BrandA', 'BrandC', 'BrandD', 'BrandE', 'BrandC', 'BrandB', 'BrandF'],
    'Price': [1200, 800, 150, 300, 50, 200, 100, 40, 600, 250],
    'UnitsSold': [30, 50, 100, 20, 75, 15, 60, 90, 25, 10],
    'Rating': [4.5, 4.7, 4.2, 4.3, 4.0, 4.1, 4.4, 4.0, 4.6, 3.9],
    'Stock': [10, 5, 25, 8, 20, 3, 12, 18, 7, 2],
    'LaunchYear': [2022, 2023, 2021, 2022, 2020, 2021, 2023, 2020, 2022, 2021]
}

df = pd.DataFrame(data)
df
# Out:
#    ProductID ProductName     Category   Brand  Price  UnitsSold  Rating  \
# 0        101      Laptop  Electronics  BrandA   1200         30     4.5
# 1        102  Smartphone  Electronics  BrandB    800         50     4.7
# 2        103  Headphones  Accessories  BrandC    150        100     4.2
# 3        104     Monitor  Electronics  BrandA    300         20     4.3
# 4        105    Keyboard  Accessories  BrandC     50         75     4.0
# 5        106  Desk Chair    Furniture  BrandD    200         15     4.1
# 6        107      Webcam  Accessories  BrandE    100         60     4.4
# 7        108       Mouse  Accessories  BrandC     40         90     4.0
# 8        109      Tablet  Electronics  BrandB    600         25     4.6
# 9        110     Printer  Electronics  BrandF    250         10     3.9
#
#    Stock  LaunchYear
# 0     10        2022
# 1      5        2023
# 2     25        2021
# 3      8        2022
# 4     20        2020
# 5      3        2021
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(df['ProductID'], df['UnitsSold'])
plt.title('Price vs Units Sold')
# Out:
# Text(0.5, 1.0, 'Price vs Units Sold')
